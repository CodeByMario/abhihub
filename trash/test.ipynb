# %%
import json
import csv

# %%
import json
import csv

# Input and output file names
json_file = "data.json"   # your JSON data file
csv_file = "output.csv"   # output CSV file

# Load JSON data from file
with open(json_file, "r", encoding="utf-8") as f:
    data = json.load(f)

# Collect all keys from all records (since some records have different fields)
all_keys = set()
for item in data:
    all_keys.update(item.keys())

all_keys = sorted(all_keys)  # optional: sort column order

# Write CSV file
with open(csv_file, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=all_keys)
    writer.writeheader()
    writer.writerows(data)

print(f"✅ Data successfully written to {csv_file}")
# Out:
# ✅ Data successfully written to output.csv

# %%
# Collect all possible keys to handle varying fields
all_keys = set()
for item in data:
    all_keys.update(item.keys())

all_keys = sorted(all_keys)  # optional: sort columns

# Write to CSV
with open("output.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=all_keys)
    writer.writeheader()
    writer.writerows(data)

# %% [markdown]
# ### Genrate the Rank

# %%
pip install pandas
``
# Out:
#   Cell In[7], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
rank = {}

data = pd.read_csv('output.csv')

for entry in data:
    print(entry)
    break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 rank = {}
#       4 data = pd.read_csv('output.csv')
#
# ModuleNotFoundError: No module named 'pandas'
